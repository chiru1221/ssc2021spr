# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import lightgbm as lgb
import optuna
import  os
from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedKFold
from utils import Optuna_for_LGB
from preprocess import convert_notation, region_encoding, region_grouping
PATH = '../data/'
TRAIN = True

# %%
train_df = pd.read_csv(PATH + 'train.csv')
test_df = pd.read_csv(PATH + 'test.csv')
train_df = convert_notation(train_df)
test_df = convert_notation(test_df)
train_df, test_df, le = region_encoding(train_df, test_df)
columns = list(test_df.columns)
columns.remove('index')
columns.remove('region')
train_df, test_df = region_grouping(train_df, test_df, columns, diff=True)
print(train_df.shape, test_df.shape)
train_df.head()
# Out:
# (4043, 68) (4046, 67)
#    index  genre  popularity  duration_ms  acousticness  positiveness  \
# 0      0     10          11       201094      0.112811      0.157247
# 1      1      8          69       308493      0.101333      0.346563
# 2      2      3          43       197225      0.496420      0.265391
# 3      3     10          45       301092      0.165667      0.245533
# 4      4      3          57       277348      0.190720      0.777578
#
#    danceability  loudness    energy  liveness  ...  \
# 0      0.187841 -1.884852  0.893918  0.363568  ...
# 1      0.554444 -5.546495  0.874409  0.193892  ...
# 2      0.457642 -9.255670  0.439933  0.217146  ...
# 3      0.356578 -5.088788  0.868704  0.377025  ...
# 4      0.830479 -3.933896  0.650149  0.169323  ...
#
#    speechiness_region_mean_diff  speechiness_region_mean_diff_region_std_diff  \
# 0                      0.190938                                      0.107738
# 1                     -0.044342                                     -0.132965
# 2                      0.168879                                      0.083626
# 3                      0.033477                                     -0.043255
# 4                      0.017855                                     -0.068502
#
#    instrumentalness_region_mean_diff  \
# 0                           0.654704
# 1                          -0.075721
# 2                          -0.032721
# 3                          -0.040311
# 4                           0.013319
#
#    instrumentalness_region_mean_diff_region_std_diff  tempo_region_mean_diff  \
# 0                                           0.482039                6.425974
# 1                                          -0.204536               -1.192626
# 2                                          -0.162285              -12.235772
# 3                                          -0.177523               -9.450292
# 4                                          -0.137564               -1.619253
#
#    tempo_region_mean_diff_region_std_diff  tempo_min_region_mean_diff  \
# 0                                0.675942                   11.464935
# 1                               -6.927914                   42.826446
# 2                              -17.632036                  -44.730229
# 3                              -14.893220                   59.953216
# 4                               -7.055886                  -13.886494
#
#    tempo_min_region_mean_diff_region_std_diff  tempo_max_region_mean_diff  \
# 0                                  -15.919090                   17.890909
# 1                                   13.881056                   41.633821
# 2                                  -72.101236                  -56.966001
# 3                                   29.820605                   50.502924
# 4                                  -41.858372                  -15.505747
#
#    tempo_max_region_mean_diff_region_std_diff
# 0                                  -12.355278
# 1                                   10.617623
# 2                                  -86.405871
# 3                                   19.607203
# 4                                  -45.344787
#
# [5 rows x 68 columns]

# %%
train_df.columns
# Out:
# Index(['index', 'genre', 'popularity', 'duration_ms', 'acousticness',
#        'positiveness', 'danceability', 'loudness', 'energy', 'liveness',
#        'speechiness', 'instrumentalness', 'tempo', 'region', 'tempo_min',
#        'tempo_max', 'popularity_mean', 'popularity_std', 'duration_ms_mean',
#        'duration_ms_std', 'acousticness_mean', 'acousticness_std',
#        'positiveness_mean', 'positiveness_std', 'danceability_mean',
#        'danceability_std', 'loudness_mean', 'loudness_std', 'energy_mean',
#        'energy_std', 'liveness_mean', 'liveness_std', 'speechiness_mean',
#        'speechiness_std', 'instrumentalness_mean', 'instrumentalness_std',
#        'tempo_mean', 'tempo_std', 'tempo_min_mean', 'tempo_min_std',
#        'tempo_max_mean', 'tempo_max_std', 'popularity_region_mean_diff',
#        'popularity_region_mean_diff_region_std_diff',
#        'duration_ms_region_mean_diff',
#        'duration_ms_region_mean_diff_region_std_diff',
#        'acousticness_region_mean_diff',
#        'acousticness_region_mean_diff_region_std_diff',
#        'positiveness_region_mean_diff',
#        'positiveness_region_mean_diff_region_std_diff',
#        'danceability_region_mean_diff',
#        'danceability_region_mean_diff_region_std_diff',
#        'loudness_region_mean_diff',
#        'loudness_region_mean_diff_region_std_diff', 'energy_region_mean_diff',
#        'energy_region_mean_diff_region_std_diff', 'liveness_region_mean_diff',
#        'liveness_region_mean_diff_region_std_diff',
#        'speechiness_region_mean_diff',
#        'speechiness_region_mean_diff_region_std_diff',
#        'instrumentalness_region_mean_diff',
#        'instrumentalness_region_mean_diff_region_std_diff',
#        'tempo_region_mean_diff', 'tempo_region_mean_diff_region_std_diff',
#        'tempo_min_region_mean_diff',
#        'tempo_min_region_mean_diff_region_std_diff',
#        'tempo_max_region_mean_diff',
#        'tempo_max_region_mean_diff_region_std_diff'],
#       dtype='object')

# %%
objective_args = {
    'num_leaves': {
        'type': 'int',
        'suggest_args': {
            'name': 'num_leaves',
            'low': 2,
            'high': 128,
        }
    },
    'max_depth': {
        'type': 'int',
        'suggest_args': {
            'name': 'max_depth',
            'low': 3,
            'high': 8,
        }
    },
    'min_data_in_leaf': {
        'type': 'int',
        'suggest_args': {
            'name': 'min_data_in_leaf',
            'low': 5,
            'high': 90,
        }
    },
    'n_estimators': {
        'type': 'int',
        'suggest_args': {
            'name': 'n_estimators',
            'low': 100,
            'high': 1000,
        }
    },
    'learning_rate': {
        'type': 'uniform',
        'suggest_args': {
            'name': 'learning_rate',
            'low': 0.0001,
            'high': 0.1
        }
    },
    'bagging_fraction': {
        'type': 'uniform',
        'suggest_args': {
            'name': 'bagging_fraction',
            'low': 0.0001,
            'high': 1.0,
        }
    },
    'feature_fraction': {
        'type': 'uniform',
        'suggest_args': {
            'name': 'feature_fraction',
            'low': 0.0001,
            'high': 1.0,
        }
    },
    'random_state': {
        'type': 'default',
        'value': 0
    },
    'objective': {
        'type': 'default',
        'value': 'cross_entropy'
    },
    'num_class': {
        'type': 'default',
        'value': 11
    },
    # 'class_weight': {
    #     'type': 'default',
    #     'value': class_weight
    # }
    
}
def evaluate_macroF1_lgb(true, pred):  
    # this follows the discussion in https://github.com/Microsoft/LightGBM/issues/1483
    pred = pred.reshape(len(np.unique(true)), -1).argmax(axis=0)
    f1 = f1_score(true, pred, average='macro')
    return ('macroF1', f1, True) 

pipeline_args = {
    'fit_attr': 'fit',
    'pred_attr': 'predict',
    'fit_args': {
        # 'X': x_train,
        # 'y': y_train,
        # 'eval_set': (x_test, y_test),
        'eval_metric': evaluate_macroF1_lgb,
        'eval_names': ['validation'],
        'early_stopping_rounds': 50,
        'verbose': -1,
        # 'feature_name': columns
        'categorical_feature': ['region']
    },
    # 'pred_args': {'X': x_test},
    'metric': lambda true, pred: f1_score(true, pred, average='macro'),
    # 'metric_args': {'true': y_test},
    'model': lgb.LGBMClassifier,
}

# %%
columns = list(test_df.columns)
columns.remove('index')
cv_num = 10
kf = StratifiedKFold(n_splits=cv_num, shuffle=True, random_state=0)
name = 'lgb_group'
x, y = train_df[columns], train_df.genre
ofl = Optuna_for_LGB()
optuna.logging.disable_default_handler()
score = list()
for cv, (train_valid_idx, test_idx) in enumerate(kf.split(np.zeros(train_df.shape[0]), y)):
    if cv <= 5:
        continue
    x_tv, x_test = x.iloc[train_valid_idx], x.iloc[test_idx]
    y_tv, y_test = y.iloc[train_valid_idx], y.iloc[test_idx]
    cv_score = list()
    for valid_cv, (train_idx, valid_idx) in enumerate(kf.split(np.zeros(x_tv.shape[0]), y_tv)):
        x_train, x_valid = x_tv.iloc[train_idx], x_tv.iloc[valid_idx]
        y_train, y_valid = y_tv.iloc[train_idx], y_tv.iloc[valid_idx]
        x_train = x_train.reset_index(drop=True)
        y_train = y_train.reset_index(drop=True)
        # x_train = region_fix(x_train, y_train, thre_count, le.transform(['unknown'])[0])
        pipeline_args['fit_args']['X'] = x_train
        pipeline_args['fit_args']['y'] = y_train
        pipeline_args['fit_args']['eval_set'] = (x_valid, y_valid)
        pipeline_args['fit_args']['feature_name'] = columns
        pipeline_args['pred_args'] = {'X': x_valid}
        pipeline_args['metric_args'] = {'true': y_valid}
        if TRAIN:
            params = ofl.parameter_tuning(pipeline_args, objective_args, 1000, -1, 0)

            best_iteration = params.pop('best_iteration_')
            model = lgb.LGBMClassifier(**params)
            model.fit(**pipeline_args['fit_args'])
            y_pred = model.predict_proba(x_test, model.best_iteration_)
            model.booster_.save_model('../model/{0}_{1}_{2}.txt'.format(name, cv, valid_cv))
        else:
            model = lgb.Booster(model_file='../model/{0}_{1}_{2}.txt'.format(name, cv, valid_cv))
            y_pred = model.predict(x_test).astype(np.float64)

        cv_score.append(f1_score(y_test, np.argmax(y_pred, axis=1), average='macro'))
    score.append(cv_score)
# Out:
# ng until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [125]	validation's multi_logloss: 0.900737	validation's macroF1: 0.648188
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [187]	validation's multi_logloss: 0.880967	validation's macroF1: 0.647203
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [162]	validation's multi_logloss: 0.894027	validation's macroF1: 0.654325
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [219]	validation's multi_logloss: 0.90904	validation's macroF1: 0.649949
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [239]	validation's multi_logloss: 0.942351	validation's macroF1: 0.626247
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [147]	validation's multi_logloss: 0.934663	validation's macroF1: 0.652328
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [166]	validation's multi_logloss: 0.901018	validation's macroF1: 0.656014
# Early stopping, best iteration is:
# [134]	validation's multi_logloss: 0.924718	validation's macroF1: 0.647717
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [140]	validation's multi_logloss: 0.900465	validation's macroF1: 0.588534
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [166]	validation's multi_logloss: 0.955114	validation's macroF1: 0.622332
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [208]	validation's multi_logloss: 0.875818	validation's macroF1: 0.659555
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [209]	validation's multi_logloss: 0.8655	validation's macroF1: 0.670166
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [170]	validation's multi_logloss: 0.896616	validation's macroF1: 0.673194
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [210]	validation's multi_logloss: 0.871429	validation's macroF1: 0.653917
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [127]	validation's multi_logloss: 0.906117	validation's macroF1: 0.66907
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [203]	validation's multi_logloss: 0.867718	validation's macroF1: 0.654331
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [111]	validation's multi_logloss: 0.924327	validation's macroF1: 0.654514
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [176]	validation's multi_logloss: 0.870832	validation's macroF1: 0.671907
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [202]	validation's multi_logloss: 0.879696	validation's macroF1: 0.667907
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [123]	validation's multi_logloss: 0.918764	validation's macroF1: 0.642337
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [157]	validation's multi_logloss: 0.88502	validation's macroF1: 0.647266
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [171]	validation's multi_logloss: 0.877456	validation's macroF1: 0.660455
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [160]	validation's multi_logloss: 0.881257	validation's macroF1: 0.651597
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [137]	validation's multi_logloss: 0.907811	validation's macroF1: 0.652031
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [154]	validation's multi_logloss: 0.895072	validation's macroF1: 0.64999
# Early stopping, best iteration is:
# [188]	validation's multi_logloss: 0.882086	validation's macroF1: 0.659783
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [195]	validation's multi_logloss: 0.888613	validation's macroF1: 0.658668
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [169]	validation's multi_logloss: 0.882394	validation's macroF1: 0.661131
# Early stopping, best iteration is:
# [168]	validation's multi_logloss: 0.88014	validation's macroF1: 0.657167
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [117]	validation's multi_logloss: 0.892938	validation's macroF1: 0.652517
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [157]	validation's multi_logloss: 0.873971	validation's macroF1: 0.64717
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [128]	validation's multi_logloss: 0.881287	validation's macroF1: 0.662639
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [121]	validation's multi_logloss: 0.882273	validation's macroF1: 0.663714
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [138]	validation's multi_logloss: 0.875603	validation's macroF1: 0.649775
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [123]	validation's multi_logloss: 0.883887	validation's macroF1: 0.632481
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [117]	validation's multi_logloss: 0.894615	validation's macroF1: 0.645768
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [133]	validation's multi_logloss: 0.877471	validation's macroF1: 0.664013
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [143]	validation's multi_logloss: 0.875933	validation's macroF1: 0.671097
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [107]	validation's multi_logloss: 0.899334	validation's macroF1: 0.660504
# Early stopping, best iteration is:
# [211]	validation's multi_logloss: 0.86597	validation's macroF1: 0.65268
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [110]	validation's multi_logloss: 0.905975	validation's macroF1: 0.637147
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [101]	validation's multi_logloss: 0.914588	validation's macroF1: 0.657734
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [94]	validation's multi_logloss: 0.951213	validation's macroF1: 0.643825
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [121]	validation's multi_logloss: 0.888098	validation's macroF1: 0.64647
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [102]	validation's multi_logloss: 0.942513	validation's macroF1: 0.631236
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [127]	validation's multi_logloss: 0.885581	validation's macroF1: 0.672091
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [128]	validation's multi_logloss: 0.88293	validation's macroF1: 0.649319
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [200]	validation's multi_logloss: 0.880757	validation's macroF1: 0.66805
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [109]	validation's multi_logloss: 0.867974	validation's macroF1: 0.665706
# Early stopping, best iteration is:
# [125]	validation's multi_logloss: 0.902918	validation's macroF1: 0.658803
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [224]	validation's multi_logloss: 0.871953	validation's macroF1: 0.663664
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [109]	validation's multi_logloss: 0.866025	validation's macroF1: 0.653837
# Early stopping, best iteration is:
# [224]	validation's multi_logloss: 0.896203	validation's macroF1: 0.649383
# Early stopping, best iteration is:
# [87]	validation's multi_logloss: 0.892697	validation's macroF1: 0.649219
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [189]	validation's multi_logloss: 0.880392	validation's macroF1: 0.650445
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [73]	validation's multi_logloss: 0.900301	validation's macroF1: 0.647677
# Early stopping, best iteration is:
# [75]	validation's multi_logloss: 0.891806	validation's macroF1: 0.654614
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [132]	validation's multi_logloss: 0.875287	validation's macroF1: 0.655319
# Early stopping, best iteration is:
# [82]	validation's multi_logloss: 0.880602	validation's macroF1: 0.670328
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [92]	validation's multi_logloss: 0.87742	validation's macroF1: 0.665457
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [132]	validation's multi_logloss: 0.935615	validation's macroF1: 0.643151
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [224]	validation's multi_logloss: 0.884376	validation's macroF1: 0.664071
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [177]	validation's multi_logloss: 0.911442	validation's macroF1: 0.654041
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [70]	validation's multi_logloss: 0.890683	validation's macroF1: 0.662391
# Early stopping, best iteration is:
# [72]	validation's multi_logloss: 0.89684	validation's macroF1: 0.6705
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [88]	validation's multi_logloss: 0.87031	validation's macroF1: 0.677621
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [157]	validation's multi_logloss: 1.21819	validation's macroF1: 0.332028
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [95]	validation's multi_logloss: 0.960482	validation's macroF1: 0.58176
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [113]	validation's multi_logloss: 0.878795	validation's macroF1: 0.652216
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [88]	validation's multi_logloss: 0.869889	validation's macroF1: 0.670372
# Early stopping, best iteration is:
# [98]	validation's multi_logloss: 0.87627	validation's macroF1: 0.657738
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [99]	validation's multi_logloss: 0.873152	validation's macroF1: 0.644092
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [103]	validation's multi_logloss: 0.869152	validation's macroF1: 0.670652
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [83]	validation's multi_logloss: 0.879943	validation's macroF1: 0.672032
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [85]	validation's multi_logloss: 0.890801	validation's macroF1: 0.660303
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [97]	validation's multi_logloss: 0.887637	validation's macroF1: 0.661568
# Early stopping, best iteration is:
# [70]	validation's multi_logloss: 0.892046	validation's macroF1: 0.659541
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [104]	validation's multi_logloss: 0.877034	validation's macroF1: 0.668371
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [63]	validation's multi_logloss: 0.905418	validation's macroF1: 0.654963
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [61]	validation's multi_logloss: 0.90372	validation's macroF1: 0.600541
# Early stopping, best iteration is:
# [76]	validation's multi_logloss: 0.889487	validation's macroF1: 0.660366
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [98]	validation's multi_logloss: 0.87877	validation's macroF1: 0.663146
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [99]	validation's multi_logloss: 0.878272	validation's macroF1: 0.661873
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [113]	validation's multi_logloss: 0.894895	validation's macroF1: 0.6542
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [45]	validation's multi_logloss: 0.945482	validation's macroF1: 0.631877
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [133]	validation's multi_logloss: 0.894409	validation's macroF1: 0.648357
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [216]	validation's multi_logloss: 0.875589	validation's macroF1: 0.651537
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [206]	validation's multi_logloss: 0.86963	validation's macroF1: 0.669865
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [149]	validation's multi_logloss: 0.892293	validation's macroF1: 0.650831
# Early stopping, best iteration is:
# [152]	validation's multi_logloss: 0.88856	validation's macroF1: 0.651876
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [117]	validation's multi_logloss: 0.901466	validation's macroF1: 0.664975
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [147]	validation's multi_logloss: 0.902478	validation's macroF1: 0.597833
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [71]	validation's multi_logloss: 0.930685	validation's macroF1: 0.625151
# Early stopping, best iteration is:
# [121]	validation's multi_logloss: 0.875208	validation's macroF1: 0.665985
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [137]	validation's multi_logloss: 0.912315	validation's macroF1: 0.630305
# Early stopping, best iteration is:
# [189]	validation's multi_logloss: 0.883175	validation's macroF1: 0.652769
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [166]	validation's multi_logloss: 0.889747	validation's macroF1: 0.663888
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [89]	validation's multi_logloss: 0.882891	validation's macroF1: 0.665783
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [149]	validation's multi_logloss: 0.868272	validation's macroF1: 0.663443
# Early stopping, best iteration is:
# [234]	validation's multi_logloss: 0.878859	validation's macroF1: 0.665923
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [53]	validation's multi_logloss: 0.912131	validation's macroF1: 0.658892
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [90]	validation's multi_logloss: 0.885794	validation's macroF1: 0.66231
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [114]	validation's multi_logloss: 0.882405	validation's macroF1: 0.656979
# Early stopping, best iteration is:
# [117]	validation's multi_logloss: 0.881086	validation's macroF1: 0.660627
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [60]	validation's multi_logloss: 0.902415	validation's macroF1: 0.630568
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [59]	validation's multi_logloss: 0.913725	validation's macroF1: 0.623841
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [116]	validation's multi_logloss: 0.88075	validation's macroF1: 0.658234
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [57]	validation's multi_logloss: 0.925158	validation's macroF1: 0.649479
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [111]	validation's multi_logloss: 0.880071	validation's macroF1: 0.607647
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [72]	validation's multi_logloss: 0.906077	validation's macroF1: 0.644127
# Early stopping, best iteration is:
# [100]	validation's multi_logloss: 0.880519	validation's macroF1: 0.654291
# Early stopping, best iteration is:
# [93]	validation's multi_logloss: 0.878074	validation's macroF1: 0.658745
# Early stopping, best iteration is:
# [103]	validation's multi_logloss: 0.874326	validation's macroF1: 0.674009
# Early stopping, best iteration is:
# [135]	validation's multi_logloss: 0.901063	validation's macroF1: 0.653362
# Early stopping, best iteration is:
# [55]	validation's multi_logloss: 0.922854	validation's macroF1: 0.659864
# Early stopping, best iteration is:
# [134]	validation's multi_logloss: 0.863787	validation's macroF1: 0.654438
# Early stopping, best iteration is:
# [93]	validation's multi_logloss: 0.880586	validation's macroF1: 0.672883
# [LightGBM] [Warning] feature_fraction is set=0.8896040364921394, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8896040364921394
# [LightGBM] [Warning] min_data_in_leaf is set=90, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=90
# [LightGBM] [Warning] bagging_fraction is set=0.4267916118312715, subsample=1.0 will be ignored. Current value: bagging_fraction=0.4267916118312715
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [183]	validation's multi_logloss: 0.863153	validation's macroF1: 0.692369

# %%
score, np.mean(score, axis=1), np.mean(score)
# Out:
# ([[0.5902938095220058,
#    0.45529333249896614,
#    0.5100288374587856,
#    0.5037402021259015,
#    0.5506471762512652,
#    0.5153526509853638,
#    0.4699787336070628,
#    0.4890624004667756,
#    0.5171116207085972,
#    0.5282922623781606],
#   [0.5684686669900216,
#    0.5145984314370303,
#    0.5106398191825999,
#    0.5696929755937685,
#    0.5158189630457843,
#    0.5552658380075003,
#    0.5317796719171406,
#    0.5714927181489052,
#    0.5912739072108569,
#    0.5423666203996015],
#   [0.49909003930123536,
#    0.505978750915096,
#    0.523172503031658,
#    0.5198383471275733,
#    0.49765957076640394,
#    0.5314841838984161,
#    0.5292033228610339,
#    0.5624964902421431,
#    0.5357368253282841,
#    0.5299577644383628],
#   [0.5018753653925706,
#    0.564852204566455,
#    0.5616459520871286,
#    0.5161911967608392,
#    0.519204233475054,
#    0.5411480930066099,
#    0.507118918884805,
#    0.5428205554581995,
#    0.5203085495722288,
#    0.552419409221917],
#   [0.5068797079301605,
#    0.6070435113863105,
#    0.5529636747028053,
#    0.4338027950684875,
#    0.6107185311759926,
#    0.5926899735372267,
#    0.6412166660236107,
#    0.5958427530623743,
#    0.6256506548268562,
#    0.6370403441096362],
#   [0.4551940607150789,
#    0.47148587990779095,
#    0.4652640739491389,
#    0.4417729202234162,
#    0.440629790768446,
#    0.4349677988310246,
#    0.511122691035768,
#    0.4799925613385968,
#    0.4626678104200957,
#    0.4796836831002263],
#   [0.6140610613757927,
#    0.6534004935159659,
#    0.6395669179213139,
#    0.6157719078809591,
#    0.5682685886789857,
#    0.6253889830786157,
#    0.6100808980822712,
#    0.5442616690265593,
#    0.523198559950746,
#    0.5922654839935404],
#   [0.4838022333717575,
#    0.5539102348408481,
#    0.520260358469566,
#    0.48495631778450404,
#    0.5353058411339524,
#    0.5369602607628716,
#    0.540761916383783,
#    0.5373951532972407,
#    0.5209380520986162,
#    0.5285927920101318],
#   [0.3984276005001022,
#    0.38044820441559307,
#    0.41820405722113557,
#    0.404159773888563,
#    0.3998363416880186,
#    0.43026389743910975,
#    0.39358258752320513,
#    0.38699637698272427,
#    0.42397761959891916,
#    0.4285881306031259],
#   [0.5159056264743104,
#    0.5012966919023462,
#    0.511345574851561,
#    0.526224405119686,
#    0.47107831213297596,
#    0.5315727103160259,
#    0.523435724903305,
#    0.5139921066348266,
#    0.5181635713422234,
#    0.5278654606576685]],
#  array([0.5129801 , 0.54713976, 0.52346178, 0.53275845, 0.58038486,
#         0.46427813, 0.59862646, 0.52428832, 0.40644846, 0.51408802]))

# %%
sub_df = pd.read_csv(PATH + 'sample_submit.csv', header=None, names=['ID', 'Pred'])
prediction = np.zeros((test_df.shape[0], 11), dtype=np.float64)
x = test_df[columns]
for i in range(cv_num):
    for j in range(cv_num):
        model = lgb.Booster(model_file='../model/{0}_{1}_{2}.txt'.format(name, i, j))
        pred = model.predict(x).astype(np.float64)
        prediction += pred
prediction /= 100.0
sub_df.Pred = np.argmax(prediction, axis=1)
sub_df.head()
# Out:
#      ID  Pred
# 0  4046     8
# 1  4047    10
# 2  4048     8
# 3  4049    10
# 4  4050     8

# %%
sub_df.Pred.hist(range=(0,11), bins=11)
# Out:
# <AxesSubplot:>

# %%
sub_df.to_csv('../pred/{0}.csv'.format(name), index=None, header=None)
